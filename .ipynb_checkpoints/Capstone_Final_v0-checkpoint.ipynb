# %% [markdown]
# # COURSERA CAPSTONE FINAL PROJECT, WEEKS 4 & 5

# %% [markdown]
# ## Find the best location to open a fitness nutrition shop in a shopping mall in Toronto

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from pprint import pprint # data pretty printer

import requests # library to handle requests
from bs4 import BeautifulSoup  # library to handle web scraping

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import folium # map rendering library

import matplotlib.cm as cm # Matplotlib and associated plotting modules
import matplotlib.colors as colors # Matplotlib and associated plotting modules

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from collections import Counter # count occurrences 

from sklearn.cluster import KMeans # import k-means from clustering stage

# %% [markdown]
# ### Import and explore Toronto postalcode areas

# %%
# import data frame
df=pd.read_csv('Toronto_neighborhoods_WithGeospacial.csv')
df.head()
# Out:
#   Postalcode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
print('The dataframe has {} boroughs and {} Neighborhood.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 Neighborhood.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto.

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# #### Create a map of Toronto with Neighborhoods superimposed on top.

# %%
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'],\
                                           df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Define Foursquare Credentials and Version

# %%
# Note that these credentials are saved in Credentials.csv which is not shared on github
Cred_data=pd.read_csv('Credentials.csv')
CLIENT_ID='5LJOJSOHCGXQDQPSJGY3GRZIHB2EJWJEL2ANTCZOUV0FIL5L'#Cred_data['CLIENT_ID'][0]
CLIENT_SECRET='TDF2G1JALYUMVXS0KRN0E4GTOV2WGPW041IBZVDKYJSGVQ43'#Cred_data['CLIENT_SECRET'][0]
VERSION=Cred_data['VERSION'][0]
LIMIT=Cred_data['LIMIT'][0]

# %% [markdown]
# **Fetch Foursquare Venue Category Hierarchy**

# %%
url = 'https://api.foursquare.com/v2/venues/categories?&client_id={}&client_secret={}&v={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION)
category_results = requests.get(url).json()

# %%
with open('category_results.json', 'w') as f:
    json.dump(category_results, f)

# %%
for key, value in category_results['response']['categories'][0].items():
    print(key, len(str(value)))
# Out:
# id 24
# name 20
# pluralName 20
# shortName 20
# icon 98
# categories 15910

# %%
category_list = category_results['response']['categories']
len(category_list)
# Out:
# 10

# %%
for data in category_list:
    print(data['id'], data['name'])
# Out:
# 4d4b7104d754a06370d81259 Arts & Entertainment
# 4d4b7105d754a06372d81259 College & University
# 4d4b7105d754a06373d81259 Event
# 4d4b7105d754a06374d81259 Food
# 4d4b7105d754a06376d81259 Nightlife Spot
# 4d4b7105d754a06377d81259 Outdoors & Recreation
# 4d4b7105d754a06375d81259 Professional & Other Places
# 4e67e38e036454776db1fb3a Residence
# 4d4b7105d754a06378d81259 Shop & Service
# 4d4b7105d754a06379d81259 Travel & Transport

# %%
Sport_ID='4d4b7105d754a06377d81259'
Shop_ID='4d4b7105d754a06378d81259'

# %% [markdown]
# **_Outdoors & Recreation_ & It's Sub-Categories**
#
# Let's create a function to return a dictionary with Ids' & Names of _Outdoors & Recreation_ & It's Sub-Categories.

# %%
# function to flatten a 'parent_id' category, returns all categories if checkParentID = False
def flatten_Hierarchy(category_list, checkParentID, category_dict, parent_id = ''):
    for data in category_list:
        
        if checkParentID == True and data['id'] == parent_id:
            category_dict[data['id']] = data['name']
            flatten_Hierarchy(category_list = data['categories'], checkParentID = False, category_dict = category_dict)
        
        elif checkParentID == False:
            category_dict[data['id']] = data['name']
            if len(data['categories']) != 0:
                flatten_Hierarchy(category_list = data['categories'], checkParentID = False, category_dict = category_dict)
    
    return category_dict

# %%
# this function takes the parent ID and returns 'name' and 'id' of all the sub-categories
category_dict = flatten_Hierarchy(category_list, checkParentID=True, category_dict = {}, parent_id = '4d4b7105d754a06377d81259')

# %%
category_dict
# Out:
# {'4d4b7105d754a06377d81259': 'Outdoors & Recreation',
#  '4f4528bc4b90abdf24c9de85': 'Athletics & Sports',
#  '52e81612bcbc57f1066b7a2b': 'Badminton Court',
#  '4bf58dd8d48988d1e8941735': 'Baseball Field',
#  '4bf58dd8d48988d1e1941735': 'Basketball Court',
#  '52e81612bcbc57f1066b7a2f': 'Bowling Green',
#  '56aa371be4b08b9a8d57351a': 'Curling Ice',
#  '4bf58dd8d48988d1e6941735': 'Golf Course',
#  '58daa1558bbb0b01f18ec1b0': 'Golf Driving Range',
#  '4bf58dd8d48988d175941735': 'Gym / Fitness Center',
#  '52f2ab2ebcbc57f1066b8b47': 'Boxing Gym',
#  '503289d391d4c4b30a586d6a': 'Climbing Gym',
#  '52f2ab2ebcbc57f1066b8b49': 'Cycle Studio',
#  '4bf58dd8d48988d105941735': 'Gym Pool',
#  '52f2ab2ebcbc57f1066b8b48': 'Gymnastics Gym',
#  '4bf58dd8d48988d176941735': 'Gym',
#  '4bf58dd8d48988d101941735': 'Martial Arts Dojo',
#  '58daa1558bbb0b01f18ec203': 'Outdoor Gym',
#  '5744ccdfe4b0c0459246b4b2': 'Pilates Studio',
#  '4bf58dd8d48988d106941735': 'Track',
#  '590a0744340a5803fd8508c3': 'Weight Loss Center',
#  '4bf58dd8d48988d102941735': 'Yoga Studio',
#  '4f452cd44b9081a197eba860': 'Hockey Field',
#  '56aa371be4b08b9a8d57352c': 'Hockey Rink',
#  '5032829591d4c4b30a586d5e': 'Paintball Field',
#  '52e81612bcbc57f1066b7a2c': 'Rugby Pitch',
#  '4bf58dd8d48988d167941735': 'Skate Park',
#  '4bf58dd8d48988d168941735': 'Skating Rink',
#  '4cce455aebf7b749d5e191f5': 'Soccer Field',
#  '52e81612bcbc57f1066b7a2e': 'Sports Club',
#  '52e81612bcbc57f1066b7a2d': 'Squash Court',
#  '4e39a956bd410d7aed40cbc3': 'Tennis Court',
#  '4eb1bf013b7b6f98df247e07': 'Volleyball Court',
#  '52e81612bcbc57f1066b7a28': 'Bathing Area',
#  '56aa371be4b08b9a8d573544': 'Bay',
#  '4bf58dd8d48988d1e2941735': 'Beach',
#  '52e81612bcbc57f1066b7a30': 'Nudist Beach',
#  '4bf58dd8d48988d1e3941735': 'Surf Spot',
#  '56aa371be4b08b9a8d57355e': 'Bike Trail',
#  '52e81612bcbc57f1066b7a22': 'Botanical Garden',
#  '4bf58dd8d48988d1df941735': 'Bridge',
#  '4bf58dd8d48988d1e4941735': 'Campground',
#  '56aa371be4b08b9a8d57353b': 'Canal Lock',
#  '56aa371be4b08b9a8d573562': 'Canal',
#  '50aaa49e4b90af0d42d5de11': 'Castle',
#  '56aa371be4b08b9a8d573511': 'Cave',
#  '4bf58dd8d48988d15c941735': 'Cemetery',
#  '52e81612bcbc57f1066b7a12': 'Dive Spot',
#  '4bf58dd8d48988d1e5941735': 'Dog Run',
#  '4bf58dd8d48988d15b941735': 'Farm',
#  '4bf58dd8d48988d15f941735': 'Field',
#  '52e81612bcbc57f1066b7a0f': 'Fishing Spot',
#  '52e81612bcbc57f1066b7a23': 'Forest',
#  '56aa371be4b08b9a8d573547': 'Fountain',
#  '4bf58dd8d48988d15a941735': 'Garden',
#  '52e81612bcbc57f1066b7a11': 'Gun Range',
#  '4bf58dd8d48988d1e0941735': 'Harbor / Marina',
#  '5bae9231bedf3950379f89cd': 'Hill',
#  '4bf58dd8d48988d160941735': 'Hot Spring',
#  '5744ccdfe4b0c0459246b4b5': 'Indoor Play Area',
#  '50aaa4314b90af0d42d5de10': 'Island',
#  '4bf58dd8d48988d161941735': 'Lake',
#  '4bf58dd8d48988d15d941735': 'Lighthouse',
#  '55a5a1ebe4b013909087cb77': 'Mountain Hut',
#  '4eb1d4d54b900d56c88a45fc': 'Mountain',
#  '52e81612bcbc57f1066b7a21': 'National Park',
#  '52e81612bcbc57f1066b7a13': 'Nature Preserve',
#  '4bf58dd8d48988d162941735': 'Other Great Outdoors',
#  '52e81612bcbc57f1066b7a14': 'Palace',
#  '4bf58dd8d48988d163941735': 'Park',
#  '52e81612bcbc57f1066b7a25': 'Pedestrian Plaza',
#  '4bf58dd8d48988d1e7941735': 'Playground',
#  '4bf58dd8d48988d164941735': 'Plaza',
#  '4bf58dd8d48988d15e941735': 'Pool',
#  '52e81612bcbc57f1066b7a29': 'Rafting',
#  '52e81612bcbc57f1066b7a26': 'Recreation Center',
#  '56aa371be4b08b9a8d573541': 'Reservoir',
#  '4eb1d4dd4b900d56c88a45fd': 'River',
#  '50328a4b91d4c4b30a586d6b': 'Rock Climbing Spot',
#  '4bf58dd8d48988d133951735': 'Roof Deck',
#  '4bf58dd8d48988d165941735': 'Scenic Lookout',
#  '4bf58dd8d48988d166941735': 'Sculpture Garden',
#  '4bf58dd8d48988d1e9941735': 'Ski Area',
#  '4bf58dd8d48988d1ea941735': 'Apres Ski Bar',
#  '4eb1c0ed3b7b52c0e1adc2ea': 'Ski Chairlift',
#  '4bf58dd8d48988d1ec941735': 'Ski Chalet',
#  '4bf58dd8d48988d1eb941735': 'Ski Lodge',
#  '4eb1c0f63b7b52c0e1adc2eb': 'Ski Trail',
#  '58daa1558bbb0b01f18ec1b9': 'Skydiving Drop Zone',
#  '4eb1baf03b7b2c5b1d4306ca': 'Stables',
#  '5bae9231bedf3950379f89d0': 'State / Provincial Park',
#  '530e33ccbcbc57f1066bbfe4': 'States & Municipalities',
#  '50aa9e094b90af0d42d5de0d': 'City',
#  '5345731ebcbc57f1066c39b2': 'County',
#  '530e33ccbcbc57f1066bbff7': 'Country',
#  '4f2a25ac4b909258e854f55f': 'Neighborhood',
#  '530e33ccbcbc57f1066bbff8': 'State',
#  '530e33ccbcbc57f1066bbff3': 'Town',
#  '530e33ccbcbc57f1066bbff9': 'Village',
#  '52e81612bcbc57f1066b7a10': 'Summer Camp',
#  '4bf58dd8d48988d159941735': 'Trail',
#  '52e81612bcbc57f1066b7a24': 'Tree',
#  '4bf58dd8d48988d1de941735': 'Vineyard',
#  '5032848691d4c4b30a586d61': 'Volcano',
#  '56aa371be4b08b9a8d573560': 'Waterfall',
#  '56aa371be4b08b9a8d5734c3': 'Waterfront',
#  '4fbc1be21983fc883593e321': 'Well',
#  '5bae9231bedf3950379f89c7': 'Windmill'}

# %% [markdown]
# Now, we have all the categories in _Outdooes and recreation_ with their id's.

# %% [markdown]
# #### Explore the first Neighborhood to understand the results of GET Request

# %% [markdown]
# Get the Neighborhood's name.

# %%
df.loc[0, 'Neighborhood']
# Out:
# 'Parkwoods'

# %% [markdown]
# Get the Neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = df.loc[0, 'Latitude'] # Neighborhood area latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # Neighborhood area longitude value

neighborhood_name = df.loc[0, 'Postalcode'] # postalcode name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of M3A are 43.7532586, -79.3296565.

# %% [markdown]
# #### Now, let's get the _Sport & Recreation_ that is in this neighborhood within a radius of 500 meters.

# %% [markdown]
# First, let's create the GET request URL to search for Venue with requested _Category ID_

# %%
LIMIT = 10 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
categoryId = '4d4b7105d754a06378d81259' # category ID for "sport and recreation"

# create URL

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius,
    categoryId,
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=5LJOJSOHCGXQDQPSJGY3GRZIHB2EJWJEL2ANTCZOUV0FIL5L&client_secret=TDF2G1JALYUMVXS0KRN0E4GTOV2WGPW041IBZVDKYJSGVQ43&v=20180604&ll=43.7532586,-79.3296565&radius=500&categoryId=4d4b7105d754a06378d81259&limit=10'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()

# %%
results['response']['venues'][0]
# Out:
# {'id': '51d769f2498e3efc78bee6b9',
#  'name': '649 Variety',
#  'location': {'lat': 43.754513133391214,
#   'lng': -79.33194239759004,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.754513133391214,
#     'lng': -79.33194239759004}],
#   'distance': 230,
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['Toronto ON', 'Canada']},
#  'categories': [{'id': '4d954b0ea243a5684a65b473',
#    'name': 'Convenience Store',
#    'pluralName': 'Convenience Stores',
#    'shortName': 'Convenience Store',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1589483043',
#  'hasPerk': False}

# %% [markdown]
# The category name of the venue **'Brookbanks Park'** is **'Parks'**.
#
# As, our aim is to segment the neighborhoods of Toronto with respect to the _Sport & Recreation_ in its vicinity. We need to proceed further to fetch this data from all the 103 neighborhoods' venues.

# %% [markdown]
# #### Let's create a function to repeat the following process to all the postalcode areas in Toronto:
# * Loop through postalcodes
#     * Create the API request URL with radius=500, LIMIT=100
#     * Make the GET request
#     * For each postalcode, return only relevant information for each nearby venue
#     * Append all nearby venues to a list
# * Unfold the list & append it to dataframe being returned

# %%
def getNearbyVenues(ID, names, latitudes, longitudes, radius=2500, LIMIT=500):
    not_found = 0
    print('***Start ', end='')
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(' .', end='')
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            ID, # category id
            LIMIT)
            
        try:
            # make the GET request
            results = requests.get(url).json()['response']['venues']
            
            # return only relevant information for each nearby venue
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['name'], 
                v['location']['lat'], 
                v['location']['lng'],  
                v['categories'][0]['name']) for v in results])
        except:
            not_found += 1


    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    print("\nDone*** with {} venues with incompelete information.".format(not_found))
    return(nearby_venues)

# %% [markdown]
# **Let's use pickle library to serialize the information retrieved from GET requests. This step will counter any redundant requests to the Foursquare API.**

# %%
import pickle # to serialize and deserialize a Python object structure
# get all sport venues
try:
    with open('Toronto_shop_venues.pkl', 'rb') as f:
        Toronto_venues = pickle.load(f)
    print("---Dataframe Existed and Deserialized---")
except:
    Toronto_venues_Sport = getNearbyVenues(ID=Sport_ID, names=df['Neighborhood'],
                                        latitudes=df['Latitude'],
                                        longitudes=df['Longitude']
                                       )
    with open('Toronto_shop_venues.pkl', 'wb') as f:
        pickle.dump(Toronto_venues, f)
    print("---Dataframe Created and Serialized---")
# Out:
# ---Dataframe Existed and Deserialized---

# %% [markdown]
# ## 3. Analysis & Machine Learning

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (4876, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Parkwoods              43.753259              -79.329656
# 1    Parkwoods              43.753259              -79.329656
# 2    Parkwoods              43.753259              -79.329656
# 3    Parkwoods              43.753259              -79.329656
# 4    Parkwoods              43.753259              -79.329656
#
#                Venue  Venue Latitude  Venue Longitude  Venue Category
# 0        Food Basics       43.760549       -79.326045     Supermarket
# 1  Bruno's valu-mart       43.746143       -79.324630   Grocery Store
# 2          Dollarama       43.760341       -79.325519  Discount Store
# 3              Metro       43.733827       -79.343479     Supermarket
# 4       Petro-Canada       43.775024       -79.333001     Gas Station

# %% [markdown]
# #### Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
Toronto_venues.groupby('Venue Category')['Venue Category'].count().sort_values(ascending=False)
# Out:
# There are 123 uniques categories.
# Venue Category
# Grocery Store                               886
# Pharmacy                                    504
# Supermarket                                 388
# Gas Station                                 384
# Shopping Mall                               350
# Liquor Store                                245
# Discount Store                              183
# Bank                                        171
# Hardware Store                              154
# Convenience Store                           116
# Electronics Store                            74
# Furniture / Home Store                       73
# Beer Store                                   70
# Automotive Shop                              69
# Shopping Plaza                               61
# Gourmet Shop                                 59
# Building                                     50
# Auto Garage                                  45
# Auto Dealership                              43
# Miscellaneous Shop                           39
# Cosmetics Shop                               39
# Pet Store                                    36
# Salon / Barbershop                           33
# Flower Shop                                  33
# Paper / Office Supplies Store                32
# Fast Food Restaurant                         31
# Butcher                                      31
# Nail Salon                                   27
# Farmers Market                               26
# Fish Market                                  24
# Department Store                             23
# Big Box Store                                22
# General Travel                               20
# Car Wash                                     19
# Warehouse Store                              19
# Lawyer                                       17
# Laundromat                                   17
# Food & Drink Shop                            17
# Laundry Service                              16
# Market                                       15
# Residential Building (Apartment / Condo)     15
# Storage Facility                             15
# Business Service                             14
# Gift Shop                                    14
# Clothing Store                               14
# Sporting Goods Shop                          14
# Fruit & Vegetable Store                      12
# Health Food Store                            12
# Shipping Store                               11
# Financial or Legal Service                   11
# Shoe Store                                   10
# Hospital                                     10
# Food Service                                  9
# Arts & Crafts Store                           9
# Construction & Landscaping                    9
# Organic Grocery                               8
# Design Studio                                 8
# Video Game Store                              7
# Event Service                                 7
# Bookstore                                     7
# Public Bathroom                               7
# Pet Service                                   7
# Juice Bar                                     7
# Cheese Shop                                   7
# Men's Store                                   7
# Watch Shop                                    6
# Real Estate Office                            6
# Post Office                                   6
# Recording Studio                              6
# Jewelry Store                                 6
# ATM                                           5
# Medical Supply Store                          5
# Waste Facility                                5
# Wine Shop                                     5
# Spa                                           5
# Recycling Facility                            5
# Mobile Phone Shop                             5
# Print Shop                                    5
# Hobby Shop                                    4
# Tanning Salon                                 4
# Bakery                                        4
# Greek Restaurant                              4
# Optical Shop                                  4
# Bike Shop                                     4
# Fireworks Store                               3
# Photography Lab                               3
# Music Store                                   3
# Restaurant                                    3
# Mattress Store                                3
# Tailor Shop                                   3
# Kids Store                                    3
# Adult Boutique                                3
# Plaza                                         3
# Boutique                                      2
# Auto Workshop                                 2
# Chocolate Shop                                2
# Bridal Shop                                   2
# IT Services                                   2
# Travel Agency                                 2
# Frame Store                                   2
# Toy / Game Store                              2
# Thrift / Vintage Store                        2
# Home Service                                  2
# Kitchen Supply Store                          2
# Office                                        2
# Record Shop                                   2
# Credit Union                                  1
# Rental Service                                1
# Accessories Store                             1
# Truck Stop                                    1
# Tattoo Parlor                                 1
# Smoke Shop                                    1
# Shop & Service                                1
# Medical Center                                1
# Currency Exchange                             1
# Lingerie Store                                1
# Brewery                                       1
# Health & Beauty Service                       1
# Garden Center                                 1
# EV Charging Station                           1
# Deli / Bodega                                 1
# Daycare                                       1
# Women's Store                                 1
# Name: Venue Category, dtype: int64

# %%
# list all the categories
unique_categories = Toronto_venues['Venue Category'].unique().tolist()
print(', '.join(str(x) for x in unique_categories))
# Out:
# Supermarket, Grocery Store, Discount Store, Gas Station, Shopping Mall, Business Service, Hardware Store, Pharmacy, Liquor Store, Fish Market, Warehouse Store, Bakery, Gourmet Shop, Bank, Shopping Plaza, Auto Dealership, Paper / Office Supplies Store, Greek Restaurant, Mattress Store, Laundromat, Electronics Store, Furniture / Home Store, Convenience Store, Car Wash, Big Box Store, Department Store, Pet Store, Miscellaneous Shop, Auto Garage, Flower Shop, General Travel, Building, Farmers Market, Market, Beer Store, Cheese Shop, Fast Food Restaurant, Shoe Store, Construction & Landscaping, Arts & Crafts Store, Lawyer, Sporting Goods Shop, Design Studio, Tanning Salon, Food Service, ATM, Nail Salon, Cosmetics Shop, Hobby Shop, Automotive Shop, Salon / Barbershop, Optical Shop, Video Game Store, Food & Drink Shop, Gift Shop, Women's Store, Butcher, Post Office, Toy / Game Store, Health Food Store, Bike Shop, Smoke Shop, Pet Service, Bookstore, Travel Agency, Storage Facility, Plaza, Juice Bar, Recycling Facility, Watch Shop, Real Estate Office, Shop & Service, Waste Facility, Fruit & Vegetable Store, Hospital, Event Service, Recording Studio, Deli / Bodega, Public Bathroom, Music Store, Thrift / Vintage Store, Laundry Service, Clothing Store, Organic Grocery, Print Shop, Bridal Shop, Health & Beauty Service, Residential Building (Apartment / Condo), Wine Shop, Financial or Legal Service, Kids Store, Mobile Phone Shop, IT Services, Tailor Shop, Men's Store, Record Shop, Photography Lab, Jewelry Store, Medical Supply Store, Boutique, Shipping Store, Restaurant, Home Service, Kitchen Supply Store, Fireworks Store, Auto Workshop, Garden Center, Tattoo Parlor, Lingerie Store, Frame Store, Spa, Office, Currency Exchange, Truck Stop, Rental Service, Daycare, Credit Union, Brewery, Adult Boutique, EV Charging Station, Chocolate Shop, Accessories Store, Medical Center

# %%
# manually create a list of most common fitness and sport related categories
general_categories = ['Shopping Mall','Shopping Plaza']

# %%
len(general_categories)
# Out:
# 2

# %% [markdown]
# Revise the results to keep only venues in the list of general categories

# %%
Toronto_venues = Toronto_venues[Toronto_venues['Venue Category'].isin(general_categories)].reset_index()
Toronto_venues.head(5)
# Out:
#    index Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0      6    Parkwoods              43.753259              -79.329656
# 1     15    Parkwoods              43.753259              -79.329656
# 2     20    Parkwoods              43.753259              -79.329656
# 3     26    Parkwoods              43.753259              -79.329656
# 4     35    Parkwoods              43.753259              -79.329656
#
#                       Venue  Venue Latitude  Venue Longitude Venue Category
# 0  Parkwoods Village Centre       43.760735       -79.324873  Shopping Mall
# 1        York Mills Gardens       43.753865       -79.358444  Shopping Mall
# 2     CF Shops at Don Mills       43.735011       -79.344787  Shopping Mall
# 3          CF Fairview Mall       43.777994       -79.343665  Shopping Mall
# 4      Parkway Forest Plaza       43.773685       -79.341569  Shopping Mall

# %% [markdown]
# ### Analyze Each neighborhood

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")
Toronto_onehot.head()
# Out:
#    Shopping Mall  Shopping Plaza
# 0              1               0
# 1              1               0
# 2              1               0
# 3              1               0
# 4              1               0

# %%
# sum all gyms
all_Shopping=Toronto_onehot['Shopping Mall']+Toronto_onehot['Shopping Plaza']
Toronto_onehot['all_Shopping']=all_Shopping
Toronto_onehot.drop(['Shopping Mall','Shopping Plaza'],axis=1,inplace=True)
Toronto_onehot.head()
# Out:
#    all_Shopping
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
Toronto_venues.shape
# Out:
# (411, 8)

# %%
Toronto_onehot.shape
# Out:
# (411, 1)

# %%
# add Postalcode column back to dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 
Toronto_onehot.head()
# Out:
#    all_Shopping Neighborhood
# 0             1    Parkwoods
# 1             1    Parkwoods
# 2             1    Parkwoods
# 3             1    Parkwoods
# 4             1    Parkwoods

# %%
# move neighborhood column to the first column
Neighborhood = Toronto_onehot['Neighborhood']

Toronto_onehot.drop(labels=['Neighborhood'], axis=1,inplace = True)
Toronto_onehot.insert(0, 'Neighborhood', Neighborhood)

Toronto_onehot.head()
# Out:
#   Neighborhood  all_Shopping
# 0    Parkwoods             1
# 1    Parkwoods             1
# 2    Parkwoods             1
# 3    Parkwoods             1
# 4    Parkwoods             1

# %% [markdown]
# And let's examine the new dataframe size.

# %%
Toronto_onehot.shape
# Out:
# (411, 2)

# %% [markdown]
# Let's count venues of each category in each neighborhood

# %%
venue_counts = Toronto_onehot.groupby('Neighborhood').sum()
venue_counts
# Out:
#                                                     all_Shopping
# Neighborhood
# Agincourt                                                     11
# Alderwood, Long Branch                                         5
# Bathurst Manor, Wilson Heights, Downsview North                3
# Bayview Village                                                5
# Bedford Park, Lawrence Manor East                              3
# Berczy Park                                                    2
# Birch Cliff, Cliffside West                                    2
# Brockton, Parkdale Village, Exhibition Place                   2
# Business reply mail Processing Centre                          2
# CN Tower, King and Spadina, Railway Lands, Harb...             1
# Caledonia-Fairbanks                                            2
# Canada Post Gateway Processing Centre                          4
# Cedarbrae                                                      2
# Central Bay Street                                             7
# Christie                                                       8
# Church and Wellesley                                           7
# Clarks Corners, Tam O'Shanter, Sullivan                        8
# Cliffside, Cliffcrest, Scarborough Village West                1
# Commerce Court, Victoria Hotel                                 6
# Davisville                                                     2
# Davisville North                                               2
# Del Ray, Mount Dennis, Keelsdale and Silverthorn               1
# Don Mills                                                     10
# Dorset Park, Wexford Heights, Scarborough Town ...             3
# Downsview                                                     10
# Dufferin, Dovercourt Village                                   3
# East Toronto                                                   3
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...             4
# Fairview, Henry Farm, Oriole                                   8
# First Canadian Place, Underground city                         7
# Forest Hill North & West                                       3
# Garden District, Ryerson                                       7
# Glencairn                                                      3
# Golden Mile, Clairlea, Oakridge                                5
# Guildwood, Morningside, West Hill                              1
# Harbourfront East, Union Station, Toronto Islands              3
# High Park, The Junction South                                  3
# Hillcrest Village                                              7
# Humber Summit                                                  1
# Humberlea, Emery                                               2
# Humewood-Cedarvale                                             5
# India Bazaar, The Beaches West                                 2
# Islington Avenue                                               2
# Kennedy Park, Ionview, East Birchmount Park                    4
# Kensington Market, Chinatown, Grange Park                      8
# Kingsview Village, St. Phillips, Martin Grove G...             1
# Lawrence Manor, Lawrence Heights                               3
# Lawrence Park                                                  2
# Leaside                                                        2
# Little Portugal, Trinity                                       4
# Malvern, Rouge                                                 2
# Milliken, Agincourt North, Steeles East, L'Amor...            13
# Mimico NW, The Queensway West, South of Bloor, ...             5
# Moore Park, Summerhill East                                    8
# New Toronto, Mimico South, Humber Bay Shores                   1
# North Toronto West                                             3
# Northwood Park, York University                                4
# Old Mill South, King's Mill Park, Sunnylea, Hum...             2
# Parkdale, Roncesvalles                                         3
# Parkview Hill, Woodbine Gardens                                5
# Parkwoods                                                      7
# Queen's Park, Ontario Provincial Government                    6
# Regent Park, Harbourfront                                      3
# Richmond, Adelaide, King                                       7
# Rosedale                                                       8
# Roselawn                                                       4
# Rouge Hill, Port Union, Highland Creek                         2
# Runnymede, Swansea                                             1
# Runnymede, The Junction North                                  2
# Scarborough Village                                            2
# South Steeles, Silverstone, Humbergate, Jamesto...             2
# St. James Town                                                 7
# St. James Town, Cabbagetown                                    7
# Steeles West, L'Amoreaux West                                 16
# Stn A PO Boxes                                                 3
# Studio District                                                1
# Summerhill West, Rathnelly, South Hill, Forest ...             8
# The Annex, North Midtown, Yorkville                            9
# The Beaches                                                    2
# The Danforth West, Riverdale                                   5
# The Kingsway, Montgomery Road, Old Mill North                  2
# Thorncliffe Park                                               1
# Toronto Dominion Centre, Design Exchange                       6
# University of Toronto, Harbord                                 8
# Upper Rouge                                                    1
# Victoria Village                                               4
# West Deane Park, Princess Gardens, Martin Grove...             3
# Westmount                                                      1
# Wexford, Maryvale                                              4
# Willowdale                                                    12
# Willowdale, Newtonbrook                                        4
# Woburn                                                         2
# Woodbine Heights                                               3
# York Mills West                                                5
# York Mills, Silver Hills                                       5

# %% [markdown]
# Let's find out the top 10 sport categories in Toronto

# %%
venue_counts_described = venue_counts.describe().transpose()

# %%
venue_top10 = venue_counts_described.sort_values('max', ascending=False)[0:10]
venue_top10
# Out:
#               count      mean       std  min  25%  50%  75%   max
# all_Shopping   95.0  4.326316  3.036803  1.0  2.0  3.0  6.5  16.0

# %%
venue_top10_list = venue_top10.index.values.tolist()

# %%
venue_top10_list
# Out:
# ['all_Shopping']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes =plt.subplots(2, 1, figsize=(15,30), sharex=True)
axes = axes.flatten()

for ax, category in zip(axes, venue_top10_list):
    data = venue_counts[[category]].sort_values([category], ascending=False)[0:10]
    pal = sns.color_palette("Blues", len(data))
    sns.barplot(x=category, y=data.index, data=data, ax=ax, palette=np.array(pal[::-1]))

plt.tight_layout()
plt.show();

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
Toronto_grouped = Toronto_onehot.groupby('Neighborhood').count().reset_index()
Toronto_grouped
# Out:
#                                          Neighborhood  all_Shopping
# 0                                           Agincourt            11
# 1                              Alderwood, Long Branch             5
# 2     Bathurst Manor, Wilson Heights, Downsview North             3
# 3                                     Bayview Village             5
# 4                   Bedford Park, Lawrence Manor East             3
# 5                                         Berczy Park             2
# 6                         Birch Cliff, Cliffside West             2
# 7        Brockton, Parkdale Village, Exhibition Place             2
# 8               Business reply mail Processing Centre             2
# 9   CN Tower, King and Spadina, Railway Lands, Har...             1
# 10                                Caledonia-Fairbanks             2
# 11              Canada Post Gateway Processing Centre             4
# 12                                          Cedarbrae             2
# 13                                 Central Bay Street             7
# 14                                           Christie             8
# 15                               Church and Wellesley             7
# 16            Clarks Corners, Tam O'Shanter, Sullivan             8
# 17    Cliffside, Cliffcrest, Scarborough Village West             1
# 18                     Commerce Court, Victoria Hotel             6
# 19                                         Davisville             2
# 20                                   Davisville North             2
# 21   Del Ray, Mount Dennis, Keelsdale and Silverthorn             1
# 22                                          Don Mills            10
# 23  Dorset Park, Wexford Heights, Scarborough Town...             3
# 24                                          Downsview            10
# 25                       Dufferin, Dovercourt Village             3
# 26                                       East Toronto             3
# 27  Eringate, Bloordale Gardens, Old Burnhamthorpe...             4
# 28                       Fairview, Henry Farm, Oriole             8
# 29             First Canadian Place, Underground city             7
# 30                           Forest Hill North & West             3
# 31                           Garden District, Ryerson             7
# 32                                          Glencairn             3
# 33                    Golden Mile, Clairlea, Oakridge             5
# 34                  Guildwood, Morningside, West Hill             1
# 35  Harbourfront East, Union Station, Toronto Islands             3
# 36                      High Park, The Junction South             3
# 37                                  Hillcrest Village             7
# 38                                      Humber Summit             1
# 39                                   Humberlea, Emery             2
# 40                                 Humewood-Cedarvale             5
# 41                     India Bazaar, The Beaches West             2
# 42                                   Islington Avenue             2
# 43        Kennedy Park, Ionview, East Birchmount Park             4
# 44          Kensington Market, Chinatown, Grange Park             8
# 45  Kingsview Village, St. Phillips, Martin Grove ...             1
# 46                   Lawrence Manor, Lawrence Heights             3
# 47                                      Lawrence Park             2
# 48                                            Leaside             2
# 49                           Little Portugal, Trinity             4
# 50                                     Malvern, Rouge             2
# 51  Milliken, Agincourt North, Steeles East, L'Amo...            13
# 52  Mimico NW, The Queensway West, South of Bloor,...             5
# 53                        Moore Park, Summerhill East             8
# 54       New Toronto, Mimico South, Humber Bay Shores             1
# 55                                 North Toronto West             3
# 56                    Northwood Park, York University             4
# 57  Old Mill South, King's Mill Park, Sunnylea, Hu...             2
# 58                             Parkdale, Roncesvalles             3
# 59                    Parkview Hill, Woodbine Gardens             5
# 60                                          Parkwoods             7
# 61        Queen's Park, Ontario Provincial Government             6
# 62                          Regent Park, Harbourfront             3
# 63                           Richmond, Adelaide, King             7
# 64                                           Rosedale             8
# 65                                           Roselawn             4
# 66             Rouge Hill, Port Union, Highland Creek             2
# 67                                 Runnymede, Swansea             1
# 68                      Runnymede, The Junction North             2
# 69                                Scarborough Village             2
# 70  South Steeles, Silverstone, Humbergate, Jamest...             2
# 71                                     St. James Town             7
# 72                        St. James Town, Cabbagetown             7
# 73                      Steeles West, L'Amoreaux West            16
# 74                                     Stn A PO Boxes             3
# 75                                    Studio District             1
# 76  Summerhill West, Rathnelly, South Hill, Forest...             8
# 77                The Annex, North Midtown, Yorkville             9
# 78                                        The Beaches             2
# 79                       The Danforth West, Riverdale             5
# 80      The Kingsway, Montgomery Road, Old Mill North             2
# 81                                   Thorncliffe Park             1
# 82           Toronto Dominion Centre, Design Exchange             6
# 83                     University of Toronto, Harbord             8
# 84                                        Upper Rouge             1
# 85                                   Victoria Village             4
# 86  West Deane Park, Princess Gardens, Martin Grov...             3
# 87                                          Westmount             1
# 88                                  Wexford, Maryvale             4
# 89                                         Willowdale            12
# 90                            Willowdale, Newtonbrook             4
# 91                                             Woburn             2
# 92                                   Woodbine Heights             3
# 93                                    York Mills West             5
# 94                           York Mills, Silver Hills             5

# %% [markdown]
# #### Let's confirm the new size

# %%
Toronto_grouped.shape
# Out:
# (95, 2)

# %% [markdown]
# #### Let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 5 venues for each neighborhood.

# %%
num_top_venues = 1

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))  
        
columns
# Out:
# ['Neighborhood', '1st Most Common Venue']

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']
neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue
# 0                                        Agincourt                   NaN
# 1                           Alderwood, Long Branch                   NaN
# 2  Bathurst Manor, Wilson Heights, Downsview North                   NaN
# 3                                  Bayview Village                   NaN
# 4                Bedford Park, Lawrence Manor East                   NaN

# %%
for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue
# 0                                        Agincourt          all_Shopping
# 1                           Alderwood, Long Branch          all_Shopping
# 2  Bathurst Manor, Wilson Heights, Downsview North          all_Shopping
# 3                                  Bayview Village          all_Shopping
# 4                Bedford Park, Lawrence Manor East          all_Shopping

# %% [markdown]
# ### Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to count Neighborhoods for each cluster label for variable cluster size

# %%
Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# %% [markdown]
# #### Determine the optimal number of clusters for k-means clustering

# %% [markdown]
# **The Elbow Method** - calculate the sum of squared distances of samples to their closest cluster center for different values of k. The value of k after which there is no siginificant decrease in sum of squared distances is choosen.

# %%
sum_of_squared_distances = []
K = range(1,5)
for k in K:
    print(k, end=' ')
    kmeans = KMeans(n_clusters=k).fit(Toronto_grouped_clustering)
    sum_of_squared_distances.append(kmeans.inertia_)
# Out:
# 1 2 3 4

# %%
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('sum_of_squared_distances')
plt.title('Elbow Method For Optimal k');

# %% [markdown]
# Elbow method does not seem to help us to determine the optimal number of clusters. Let's use another method.
#
# **The Silhouette Method** - The silhouette value measures how similar a point is to its own cluster (cohesion) compared to other clusters (separation). Source: Wikipedia

# %%
from sklearn.metrics import silhouette_score

sil = []
K_sil = range(2,3)
# minimum 2 clusters required, to define dissimilarity
for k in K_sil:
    print(k, end=' ')
    kmeans = KMeans(n_clusters = k).fit(Toronto_grouped_clustering)
    labels = kmeans.labels_
    sil.append(silhouette_score(Toronto_grouped_clustering, labels, metric = 'euclidean'))
# Out:
# 2

# %%
plt.plot(K_sil, sil, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette_score')
plt.title('Silhouette Method For Optimal k')
plt.show()

# %%
pd.DataFrame({'Sil':sil,'ksil':K_sil}).head(15)
# Out:
#         Sil  ksil
# 0  0.681052     2

# %% [markdown]
# #### There is a peak at k = 6.
# ### Let's set number of clusters = 6

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(init="k-means++", n_clusters=kclusters, n_init=50).fit(Toronto_grouped_clustering)

print(Counter(kmeans.labels_))
# Out:
# Counter({2: 59, 0: 30, 1: 6})

# %%
kmeans.labels_
# Out:
# array([1, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 2, 2,
#        1, 2, 1, 2, 2, 2, 0, 0, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 1, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 0, 0, 2,
#        2, 2, 2, 2, 2, 0, 0, 1, 2, 2, 0, 0, 2, 0, 2, 2, 0, 0, 2, 2, 2, 2,
#        2, 1, 2, 2, 2, 0, 0], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 5 venues for each neighborhood.

# %%
# add clustering labels
try:
    neighborhoods_venues_sorted.drop('Cluster Labels', axis=1)
except:
    neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels                                     Neighborhood  \
# 0               2                                        Agincourt
# 1               4                           Alderwood, Long Branch
# 2               0  Bathurst Manor, Wilson Heights, Downsview North
# 3               4                                  Bayview Village
# 4               0                Bedford Park, Lawrence Manor East
#
#   1st Most Common Venue
# 0          all_Shopping
# 1          all_Shopping
# 2          all_Shopping
# 3          all_Shopping
# 4          all_Shopping

# %%
# merge neighborhoods_venues_sorted with Toronto_data to add latitude/longitude for each neighborhood
Toronto_merged = neighborhoods_venues_sorted.join(df.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged.head()
# Out:
#    Cluster Labels                                     Neighborhood  \
# 0               2                                        Agincourt
# 1               4                           Alderwood, Long Branch
# 2               0  Bathurst Manor, Wilson Heights, Downsview North
# 3               4                                  Bayview Village
# 4               0                Bedford Park, Lawrence Manor East
#
#   1st Most Common Venue Postalcode      Borough   Latitude  Longitude
# 0          all_Shopping        M1S  Scarborough  43.794200 -79.262029
# 1          all_Shopping        M8W    Etobicoke  43.602414 -79.543484
# 2          all_Shopping        M3H   North York  43.754328 -79.442259
# 3          all_Shopping        M2K   North York  43.786947 -79.385975
# 4          all_Shopping        M5M   North York  43.733283 -79.419750

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
colors_array = cm.rainbow(np.linspace(0, 1, kclusters))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-94-e9a1300136f1> in <module>
#      14         radius=5,
#      15         popup=label,
# ---> 16         color=rainbow[cluster-1],
#      17         fill=True,
#      18         fill_color=rainbow[cluster-1],
#
# IndexError: list index out of range

# %% [markdown]
# ## 5. Results

# %%
required_column_indices = [2,3,5]
required_column = [list(Toronto_merged.columns.values)[i] for i in required_column_indices]
required_column_indices = [2,3,5]

# %% [markdown]
# #### Cluster 0

# %%
cluster_0 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[1:12]]
cluster_0.head()
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 2     Bathurst Manor, Wilson Heights, Downsview North          all_Shopping
# 4                   Bedford Park, Lawrence Manor East          all_Shopping
# 11              Canada Post Gateway Processing Centre          all_Shopping
# 23  Dorset Park, Wexford Heights, Scarborough Town...          all_Shopping
# 25                       Dufferin, Dovercourt Village          all_Shopping
#
#    Postalcode       Borough   Latitude  Longitude
# 2         M3H    North York  43.754328 -79.442259
# 4         M5M    North York  43.733283 -79.419750
# 11        M7R   Mississauga  43.636966 -79.615819
# 23        M1P   Scarborough  43.757410 -79.273304
# 25        M6H  West Toronto  43.669005 -79.442259

# %%
for col in required_column:
    print(cluster_0[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# all_Shopping    25
# Name: 1st Most Common Venue, dtype: int64
# ---------------------------------------------
# M2M    1
# M7R    1
# M3J    1
# M1R    1
# M6A    1
# M4J    1
# M6J    1
# M5P    1
# M9B    1
# M5J    1
# M4A    1
# M6P    1
# M5M    1
# M6B    1
# M6R    1
# M4C    1
# M6H    1
# M5A    1
# M9C    1
# M5N    1
# M1P    1
# M4R    1
# M1K    1
# M5W    1
# M3H    1
# Name: Postalcode, dtype: int64
# ---------------------------------------------
# 43.715383    1
# 43.636966    1
# 43.643515    1
# 43.650943    1
# 43.685347    1
# 43.646435    1
# 43.754328    1
# 43.750071    1
# 43.789053    1
# 43.647927    1
# 43.669005    1
# 43.648960    1
# 43.757410    1
# 43.711695    1
# 43.696948    1
# 43.725882    1
# 43.718518    1
# 43.695344    1
# 43.767980    1
# 43.640816    1
# 43.654260    1
# 43.661608    1
# 43.733283    1
# 43.709577    1
# 43.727929    1
# Name: Latitude, dtype: int64
# ---------------------------------------------

# %% [markdown]
# #### Cluster 1

# %%
cluster_1 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[1:12]]
cluster_1.head()
# Out:
#                                Neighborhood 1st Most Common Venue Postalcode  \
# 13                       Central Bay Street          all_Shopping        M5G
# 14                                 Christie          all_Shopping        M6G
# 15                     Church and Wellesley          all_Shopping        M4Y
# 16  Clarks Corners, Tam O'Shanter, Sullivan          all_Shopping        M1T
# 22                                Don Mills          all_Shopping        M3B
#
#              Borough   Latitude  Longitude
# 13  Downtown Toronto  43.657952 -79.387383
# 14  Downtown Toronto  43.669542 -79.422564
# 15  Downtown Toronto  43.665860 -79.383160
# 16       Scarborough  43.781638 -79.304302
# 22        North York  43.745906 -79.352188

# %%
for col in required_column:
    print(cluster_1[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# all_Shopping    24
# Name: 1st Most Common Venue, dtype: int64
# ---------------------------------------------
# M2H    1
# M3K    1
# M4X    1
# M3N    1
# M5B    1
# M3A    1
# M3C    1
# M3B    1
# M5T    1
# M5H    1
# M4V    1
# M5G    1
# M1T    1
# M3M    1
# M5X    1
# M4T    1
# M5C    1
# M5R    1
# M2J    1
# M4Y    1
# M3L    1
# M5S    1
# M4W    1
# M6G    1
# Name: Postalcode, dtype: int64
# ---------------------------------------------
# 43.665860    1
# 43.778517    1
# 43.689574    1
# 43.679563    1
# 43.651494    1
# 43.781638    1
# 43.728496    1
# 43.653206    1
# 43.669542    1
# 43.657952    1
# 43.667967    1
# 43.761631    1
# 43.803762    1
# 43.739015    1
# 43.745906    1
# 43.686412    1
# 43.753259    1
# 43.657162    1
# 43.737473    1
# 43.725900    1
# 43.650571    1
# 43.662696    1
# 43.672710    1
# 43.648429    1
# Name: Latitude, dtype: int64
# ---------------------------------------------

# %% [markdown]
# #### Cluster 2

# %%
cluster_2 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[1:12]]
cluster_2.head()
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                                           Agincourt          all_Shopping
# 51  Milliken, Agincourt North, Steeles East, L'Amo...          all_Shopping
# 73                      Steeles West, L'Amoreaux West          all_Shopping
# 89                                         Willowdale          all_Shopping
# 89                                         Willowdale          all_Shopping
#
#    Postalcode      Borough   Latitude  Longitude
# 0         M1S  Scarborough  43.794200 -79.262029
# 51        M1V  Scarborough  43.815252 -79.284577
# 73        M1W  Scarborough  43.799525 -79.318389
# 89        M2N   North York  43.770120 -79.408493
# 89        M2R   North York  43.782736 -79.442259

# %%
for col in required_column:
    print(cluster_2[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# all_Shopping    5
# Name: 1st Most Common Venue, dtype: int64
# ---------------------------------------------
# M1V    1
# M2N    1
# M2R    1
# M1W    1
# M1S    1
# Name: Postalcode, dtype: int64
# ---------------------------------------------
# 43.770120    1
# 43.794200    1
# 43.782736    1
# 43.799525    1
# 43.815252    1
# Name: Latitude, dtype: int64
# ---------------------------------------------

# %% [markdown]
# #### Cluster 3

# %%
cluster_3 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[1:12]]
cluster_3.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 5                                        Berczy Park          all_Shopping
# 6                        Birch Cliff, Cliffside West          all_Shopping
# 7       Brockton, Parkdale Village, Exhibition Place          all_Shopping
# 8              Business reply mail Processing Centre          all_Shopping
# 9  CN Tower, King and Spadina, Railway Lands, Har...          all_Shopping
#
#   Postalcode           Borough   Latitude  Longitude
# 5        M5E  Downtown Toronto  43.644771 -79.373306
# 6        M1N       Scarborough  43.692657 -79.264848
# 7        M6K      West Toronto  43.636847 -79.428191
# 8        M7Y      East Toronto  43.662744 -79.321558
# 9        M5V  Downtown Toronto  43.628947 -79.394420

# %%
for col in required_column:
    print(cluster_3[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# all_Shopping    34
# Name: 1st Most Common Venue, dtype: int64
# ---------------------------------------------
# M8X    1
# M6S    1
# M1G    1
# M9L    1
# M6E    1
# M1H    1
# M1N    1
# M8Y    1
# M8V    1
# M4G    1
# M1M    1
# M1C    1
# M4M    1
# M7Y    1
# M4L    1
# M9M    1
# M6M    1
# M9P    1
# M9V    1
# M1J    1
# M9R    1
# M5E    1
# M9A    1
# M6N    1
# M6K    1
# M4N    1
# M1B    1
# M1X    1
# M1E    1
# M4P    1
# M4H    1
# M4S    1
# M5V    1
# M4E    1
# Name: Postalcode, dtype: int64
# ---------------------------------------------
# 43.739416    1
# 43.744734    1
# 43.836125    1
# 43.673185    1
# 43.667856    1
# 43.705369    1
# 43.724766    1
# 43.636258    1
# 43.659526    1
# 43.704324    1
# 43.651571    1
# 43.712751    1
# 43.763573    1
# 43.636847    1
# 43.605647    1
# 43.784535    1
# 43.691116    1
# 43.709060    1
# 43.676357    1
# 43.662744    1
# 43.773136    1
# 43.716316    1
# 43.628947    1
# 43.653654    1
# 43.668999    1
# 43.692657    1
# 43.806686    1
# 43.770992    1
# 43.728020    1
# 43.689026    1
# 43.696319    1
# 43.756303    1
# 43.644771    1
# 43.688905    1
# Name: Latitude, dtype: int64
# ---------------------------------------------

# %% [markdown]
# #### Cluster 4

# %%
cluster_4 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[1:12]]
cluster_4.head(5)
# Out:
#                        Neighborhood 1st Most Common Venue Postalcode  \
# 1            Alderwood, Long Branch          all_Shopping        M8W
# 3                   Bayview Village          all_Shopping        M2K
# 18   Commerce Court, Victoria Hotel          all_Shopping        M5L
# 33  Golden Mile, Clairlea, Oakridge          all_Shopping        M1L
# 40               Humewood-Cedarvale          all_Shopping        M6C
#
#              Borough   Latitude  Longitude
# 1          Etobicoke  43.602414 -79.543484
# 3         North York  43.786947 -79.385975
# 18  Downtown Toronto  43.648198 -79.379817
# 33       Scarborough  43.711112 -79.284577
# 40              York  43.693781 -79.428191

# %%
for col in required_column:
    print(cluster_4[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# all_Shopping    12
# Name: 1st Most Common Venue, dtype: int64
# ---------------------------------------------
# M2K    1
# M7A    1
# M4K    1
# M2P    1
# M1L    1
# M8W    1
# M4B    1
# M5K    1
# M5L    1
# M6C    1
# M8Z    1
# M2L    1
# Name: Postalcode, dtype: int64
# ---------------------------------------------
# 43.647177    1
# 43.662301    1
# 43.786947    1
# 43.752758    1
# 43.757490    1
# 43.648198    1
# 43.628841    1
# 43.711112    1
# 43.602414    1
# 43.679557    1
# 43.706397    1
# 43.693781    1
# Name: Latitude, dtype: int64
# ---------------------------------------------

# %% [markdown]
# #### Cluster 5

# %%
cluster_5 = Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 5, Toronto_merged.columns[1:12]]
cluster_5
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, Postalcode, Borough, Latitude, Longitude]
# Index: []

# %%
for col in required_column:
    print(cluster_5[col].value_counts(ascending = False))
    print("---------------------------------------------")
# Out:
# Series([], Name: 1st Most Common Venue, dtype: int64)
# ---------------------------------------------
# Series([], Name: Postalcode, dtype: int64)
# ---------------------------------------------
# Series([], Name: Latitude, dtype: int64)
# ---------------------------------------------
